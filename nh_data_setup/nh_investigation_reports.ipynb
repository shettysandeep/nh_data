# %% [markdown]
# ## Working with Nursing Home Complaints data.
# __author__: sandeep
# __date__: Mar 20, 2023
#
# ### about the data...
# - The data includes Nursing Home (NH)-level statistics as well investigation reports associated with f-tags.
# - NHs can receive more than one f-tag in each investigation or response to complaints.
# - NHs can receive more than one f-tags across many different years.
#
# ### focus here...
# Mainly interested in information retrieval from the investigation reports.
# - the investigation reports include
#     - parties involved - Residents (R); Licensed Physician's Nurse (LPN); etc. referred as LPN#1, etc.
#     - dates listed of interaction, complaints, and general progress in resolution
#
# *so the focus -->*
# - who is the complaint against?
# - who is the complainant?
# - what is the event mentioned in the complaint?
# - are there more than one person complained against?
# - extract symptoms from the text - apply clinical NER model
# - how to use the text extracted in the modeling problem
#
#
# ### potential approaches...
# - regex methods to extract key actors
# - build a word embedding with this data to extract similarities, etc
# - NLTK chunking to extract syntax-based verb chunks to identify actions

# %%
# packages needed
import pandas as pd
import re
import spacy
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

# %%
nlp = spacy.load("en_core_web_sm")

# %%
# data snapshot - saved locally
dat = pd.read_csv("./merged_data/text2567_20190501_cms_reg1.csv", index_col=0, dtype=str)

# %%
txt_rep=dat[['inspection_text','deficiency_tag', 'scope_severity', 'complaint']].copy() # subset of columns
txt_rep.inspection_text = txt_rep.inspection_text.str.lower().str.replace("<br/?>","", regex=True)
txt_rep.inspection_text = txt_rep.inspection_text.str.replace("(\s?\#\s?)","#", regex=True)

# %%
# identify key actors in a given report -  OPTION 1

def find_actors(txt):
    # list 1
    person_list0 = list(set(re.findall("\s([a-z]*\#[0-9]*)",txt)))
    print(person_list0)
    person_list=[]
    doc = nlp(txt)
    for tk in doc.sents:
        for sent in tk.ents:
            if sent.label==380:
                person_list.append(sent.text)
    print(list(set(person_list)))
    person_list = set(person_list + person_list0)
    return person_list # find hospital staff involved

txt_rep['actors']=txt_rep.inspection_text.map(find_actors)
#txt_rep.actors=txt_rep.actors.apply(lambda x: [re.sub("resident", "r", ax) if 'resident' in ax else ax for ax in x ])
# Out:
# ['lpn#1', 'lpn#2', 'resident#312', 'person#1']
# ['lpn#2']
# ['person#4', 'na#7', 'r#227', 'sw#1', 'rn#1', 'lpn#3', 'na#6', 'resident#227']
# ['na#6', 'r#227']
# ['person#4', 'na#7', 'r#227', 'sw#1', 'rn#1', 'lpn#3', 'resident#227']
# ['r#227']
# []
# []
# ['lpn#1', 'lpn#2', 'resident#312', 'person#1']
# ['lpn#2']
# ['na#4', 'adns#2', 'resident#183', 'na#2']
# []
# ['person#2', 'resident#347', 'sw#1', 'adns#2']
# []
# ['na#11', 'resident#43', 'rn#7', 'housekeeper#1']
# ['resident#43']
# ['room#320', 'room#319', 'room#303', 'and#320']
# []
# ['resident#180', 'na#1', 'person#4', 'na#4', 'resident#349', 'rn#1', 'rn#2', 'na#2', 'receptionist#2']
# ["b. resident#180's", "a. resident#180's"]
# ['rn#8', 'lpn#5', 'lpn#6', 'resident#60']
# ['resident#60']
# ['resident#347']
# []
# ['resident#347']
# []
# ['aprn#1']
# ['4/9/18']
# []
# ['room.10', 'brown']
# ['sw#1', 'resident#644', 'na#3', 'na#2', 'adon#1']
# []
# ['resident#40', 'resident#92', 'adns#2']
# ["c. resident#92's", 'resident#92', "a. resident#40's"]
# ['resident#744', 'resident#175']
# ['cm']
# ['resident#645', 'person#4', 'rn#3', 'ot#2', 'rn#6', 'resident#175', 'lpn#9', 'na#2', 'receptionist#2', 'resident#227', 'adon#3', 'na#8']
# ["a. resident#175's", "c. resident#645's", 'person#4', 'cm', 'don', 'receptionist#2', 'b. resident#227']
# ['aprn#2']
# ['4/9/18', 'don']
# ['rn#4', 'lpn#7']
# ['chin strap']
# ['resident#40']
# ['resident#40']
# ['da#1', 'da#2']
# []
# []
# []
# ['hk#1', 'hk#4']
# ['hk#4']
# []
# []
# ['rn#1', 'adns#2']
# ['and/or brown stains', 'e. observation', 'lpn)#5', 'brown']
# []
# []
# ['housekeeper#1', 'resident#97', 'resident#123', 'person#2', 'resident#50', 'resident#45', 'rn#1', 'resident#16', 'lpn#3', 'resident#3', 'resident#23', 'nurse#2', 'and#132', 'resident#8', 'assistant#1']
# ['resident#45', 'resident#3']
# ['resident#111']
# []
# ['resident#97']
# ['resident#97']
# ['resident#44']
# []
# []
# []
# ['resident#44']
# []
# ['lpn#3', 'rn#1', 'resident#78', 'na#2']
# []
# ['lpn#4', 'resident#21']
# ['lpn#4']
# ['staff#1', 'lpn#2']
# ['maintenance log', 'lpn#2']
# ['lpn#1']
# []
# ['lpn#1', 'resident#38']
# ['resident#38']
# ['ns#1', 'na#2', 'resident#58']
# ['resident#58']
# []
# []
# ['na#4', 'lpn#6', 'resident#24', 'lpn#4', 'lpn#3']
# ['lpn#4', 'resident#24']
# ['rn#6', 'resident#386', 'rn#2']
# []
# ['resident#9', 'na#3', 'na#2']
# []
# ['rn#1']
# []
# ['rn#4', 'rn#3', 'setting#5', 'resident#6']
# ['material.interview', 'setting#5', 'foley catheter']
# ['resident#1']
# ['cm']
# ['resident#1']
# []
# ['resident#71', 'lpn#2', 'na#2']
# ['resident#71', 'lpn#2']
# ['resident#71', 'lpn#2']
# ['resident#71', 'lpn#2']
# ['resident#138', 'lpn#2', 'na#3', 'ot#3']
# ['resident#138', 'lpn#2']
# ['resident#12']
# []
# ['staff#1', 'staff#2']
# []
# ['resident#5', 'ot#3']
# []
# ['aprn#1', 'resident#1', 'person#1']
# []
# ['na#1', 'and#2', 'resident#3', 'na#2']
# ['don', 'na#1', 'foley', 'resident#3']
# ['resident#60', 'resident#40', 'lpn#1']
# ['resident#60']
# ['lpn#2', 'resident#85']
# ['lpn#2']
# ['resident#79', 'rn#3', 'md#1', 'resident#5', 'aprn#2', 'rn#1', 'resident#47', 'lpn#5', 'representative#1', 'resident#19']
# ['resident#79', 'nurse', 'resident#47', 'lpn#5', 'resident#19']
# ['pt#1', 'rn#1', 'aprn#1', 'resident#60', 'resident#82']
# ['don', 'resident#82', 'resident#60']
# ['rn#4', 'lpn#6', 'resident#62']
# ['provastatin', 'resident#62']
# ['na#3']
# []
# ['rn#3', 'resident#1', 'lpn#1', 'rn#1', 'person#1', 'aprn#1']
# []
# ['resident#1', 'lpn#1', 'rn#1']
# []
# ['resident#1', 'lpn#1', 'rn#1']
# []
# ['rn#3', 'lpn#1', 'rn#1', 'r#1', 'aprn#1']
# ['don', 'rn#1']
# ['r#1']
# []
# ['resident#78', 'person#1']
# []
# ['md#1', 'resident#41', 'person#3', 'dietitian#1', 'resident#103', 'lpn#3', 'dietician#1']
# ['7/2/18', 'resident#41', 'redacted].physician']
# ['person#2', 'resident#41', 'resident#43', 'scheduler#1', 'resident#46']
# ['resident#43', 'resident#41']
# ['lpn#4', 'na#3', 'rn#5', 'lpn#5', 'resident#102']
# ['lpn#4', 'lpn#5']
# ['na#1', 'resident#41', 'lpn#1']
# ['resident#41']
# ['na#1', 'resident#41', 'lpn#1']
# ['resident#41']
# ['na#1', 'resident#41', 'person#3', 'rn#1', 'pt#2', 'ot#1']
# ['resident#41']
# ['na#1', 'resident#41', 'worker#1', 'person#3']
# ['resident#41']
# ['lpn#6', 'md#1', 'resident#41', 'person#3', 'resident#95']
# ['resident#41', 'redacted].physician', 'mar', 'resident#95']
# ['na#1', 'person#2', 'resident#41', 'person#3', 'resident#43', 'scheduler#1', 'resident#46']
# ['resident#43', 'resident#41']
# ['resident#89', 'lpn#1']
# ['resident#89']
# ['md#1', 'resident#41', 'person#3', 'dietitian#1', 'dietician#1']
# ['resident#41', 'redacted].physician', 'mar']
# ['resident#79', 'lpn#2', 'resident#16']
# ['lpn#2']
# ['na#2', 'scheduler#1', 'resident#46']
# []
# ['na#1', 'rn#3', 'resident#42', 'lpn#1', 'resident#154', 'rn#1', 'resident#47', 'rn#2', 'resident#8', 'resident#70']
# ['foley', 'resident#47', 'don gloves.4a', 'e. coli', 'resident#70']
# ['na#1', 'rn#1', 'md#1', 'resident#115']
# ['resident#115']
# ['na#5', 'resident#1', 'r#1', 'na#2']
# ["a. r#1's"]
# ['r#1']
# ["a. r#1's"]
# ['lpn#2', 'resident#1', 'r#1', 'lpn#1']
# ["a. r#1's", 'lpn#2']
# ['resident#1', 'r#1', 'na#2']
# ["a. r#1's", 'na#2']
# ['resident#1', 'lpn#2', 'and#2', 'lpn#1']
# ['lpn#2']
# ['na#5', 'resident#1', 'r#1', 'na#2']
# ["a. r#1's"]
# ['resident#1', 'na#2']
# []
# ['resident#1', 'aprn#2', 'r#2', 'resident#2', 'aprn#1']
# []
# ['resident#67', 'rn#2']
# []
# ['rn#4', 'resident#348', 'md#1', 'person#1']
# []
# ['agency#2', 'agency#1', 'dme#1', 'manager#2', 'person#1', 'manager#1', 'provider#2', 'person#248', 'provider#1']
# []
# ['tech#1', 'resident#249', 'rn#1', 'resident#7', 'and#249', 'resident#19']
# ['physician']
# ['na#1', 'resident#67', 'md#2', 'rn#2']
# ['resident#67']
# ['resident#67', 'rn#2']
# ['resident#67']
# ['cook#1', 'cook#2']
# []
# ['rn#3']
# []
# ['resident#7', 'resident#61']
# ['ppsv23']
# ['resident#92']
# ['resident#92 and/or']
# ['na#1', 'resident#162', 'resident#74', 'lpn#1', 'na#3', 'resident#7', 'lpn#3', 'resident#363', 'resident#23', 'resident#91']
# ['resident#91']
# ['resident#7', 'lpn#1', 'rn#1']
# []
# ['resident#112', 'pharmacist#1', 'lpn#1', 'resident#113', 'rn#2', 'resident#91']
# []
# ['resident#39', 'and#113', 'residents#91', 'lpn#1', 'rn#2']
# []
# ['resident#47', 'na#1']
# ['resident#47', 'demeanor.interview']
# ['resident#68']
# ['resident#68']
# ['resident#15', 'resident#16', 'lpn#1', 'lpn#3']
# ['don', 'resident#15']
# []
# []
# ['lpn#2', 'resident#16']
# ['lpn#2']
# ['na#1', 'resident#1', 'rn#1', 'na#2']
# ['don']
# ['resident#26', 'na#5', 'na#1', 'lpn#2', 'and#33', 'resident#33', 'lpn#1', 'resident#17', 'na#6']
# ['don', 'lpn#2', 'na#6']
# ['and#56']
# []
# ['resident#17', 'lpn#2', 'na#1', 'na#5']
# ['lpn#2']
# ['resident#62']
# ['resident#62']
# ['r#56', 'r#30', 'r#33', 'na#7', 'r#36', 'r#8', 'r#49', 'r#43', 'na#9', 'r#41', 'na#6']
# ['r#41', 'na#7', 'needed.a', 'na#6']
# ['cook#1']
# []
# ['resident#32', 'lpn#2', 'md#1']
# ['lpn#2']
# ['cook#1']
# []
# ['na#1', 'resident#1', 'lpn#1']
# ['don']
# ['officer#1']
# []
# ['rn#3', 'rn#1', 'resident#2', 'lpn#3', 'rn#2']
# ['dti']
# ['resident#13', 'rn#2']
# ['resident#13']
# ['rn#3', 'rn#1', 'resident#2', 'lpn#3', 'rn#2']
# ['dti']
# ['housekeeper#1', 'na#1', 'lpn#1', 'resident#4', 'rn#2']
# ['redacted].#4', 'resident#4']
# ['resident#8']
# ['decrease)review']
# ['rn#3']
# []
# []
# []
# ['resident#35', 'resident#1', 'resident#23', 'rn#4', 'resident#13', 'resident#12']
# ['c. adults', 'ppsv23', 'resident#13']
# ['rn#5']
# []
# ['resident#26', 'rn#4']
# []
# ['na#1', 'resident#343', 'rn#1', 'r#343']
# ['nurse']
# ['resident#343', 'r#343']
# []
# ['rn#5', 'resident#9', 'md#1']
# ['physician']
# ['lpn#2', 'resident#65', 'lpn#1']
# ['lpn#2', 'orange juice', 'resident#65']
# ['resident#252']
# []
# ['resident#252', 'na#1', 'na#4', 'na#3', 'rn#1', 'na#2']
# ['calmer']
# ['resident#252', 'rn#1']
# ['b.resident#252', 'resident#252']
# ['resident#249', 'and#254', 'lpn#1', 'resident#215', 'resident#109', 'resident#254', 'resident#19']
# []
# ['resident#85', 'sw#1']
# []
# ['rn#1']
# []
# ['lpn#2', 'lpn#6', 'lpn#7', 'lpn#4', 'lpn#1', 'lpn#8', 'rn#1', 'lpn#5', 'lpn#3']
# ['lpn#2', 'c. observation', 'lpn#4', 'clean.j', 'lpn#5']
# ['da#1', 'da#2', 'da#3']
# ['da#3']
# ['lpn#6', 'resident#134']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['resident#2', 'lpn#3']
# []
# ['contractor#1', 'c#1']
# ['c#1']
# ['resident#2', 'lpn#3']
# []
# ['cook#1', 'rn#3', 'md#1', 'na#2', 'rn#2', 'resident#3']
# ['resident#3']
# ['na#1', 'lpn#2', 'cs#1', 'resident#1', 'lpn#1', 'rn#1', 'r#13', 'r#1', 'resident#13', 'supervisor#1']
# ['resident#13', 'lpn#2']
# ['resident#2', 'na#3', 'na#2']
# []
# ['lpn#2', 'rp#1', 'party#1', 'resident#53', 'resident#109', 'r#53']
# ['lpn#2']
# ['lpn#2', 'resident#9']
# ['lpn#2']
# ['resident#190']
# []
# []
# ['c. observation']
# ['resident#225', 'rp#1', 'lpn#2', 'party#1', 'and#295', 'rn#5', 'resident#53', 'resident#109', 'resident#295', 'r#53']
# ["a. resident#225's", 'lpn#2', "c. resident#53's"]
# ['resident#190']
# []
# ['and#5', 'resident#5', 'resident#4']
# []
# ['na#1', 'lpn#2', 'resident#1', 'na#3', 'lpn#3']
# ['lpn#2', 'na#3']
# ['na#1', 'resident#1', 'lpn#2', 'na#3']
# ['lpn#2', 'na#3']
# ['na#1', 'na#5', 'and#4', 'rn#1', 'resident#2', 'resident#4', 'lpn#3', 'resident#3', 'na#2']
# ['don', 'resident#3']
# ['resident#3', 'na#2']
# ['resident#3']
# ['resident#55', 'md#1']
# ['resident#55']
# ['na#1', 'resident#87', 'lpn#2', 'na#2']
# ['don', 'na#1', 'lpn#2', 'na#2']
# ['rn#5', 'resident#92', 'rn#7', 'resident#104']
# ['resident#92 and/or', 'redacted].physician', 'resident#92']
# ['resident#18', 'rn#5']
# []
# ['rn#6', 'resident#404', 'lpn#1']
# ['boggy heels']
# ['lpn#4', 'resident#37']
# ['lpn#4', 'physician']
# ['na#1', 'resident#87', 'na#2']
# ['don', 'na#1', 'na#2']
# ['resident#55', 'md#1']
# ['resident#55']
# ['rn#6', 'rn#3', 'rn#2', 'rn#1']
# ['influenza', 'year)/2018']
# ['rn#6', 'rn#3', 'rn#1']
# []
# ['na#4', 'rn#3', 'na#3', 'rn#1', 'rn#6', 'resident#27', 'resident#37']
# ['resident#27']
# ['lpn#5']
# []
# ['resident#62']
# ['resident#62']
# ['resident#256', 'aide#6', 'resident#606', 'and#606', 'aide#5', 'na#8']
# ['4/9/18', 'resident#256']
# ['na#1', 'r#155']
# []
# ['na#7', 'rn#3', 'resident#100', 'ot#2']
# []
# ['lpn#4', 'r#140', 'nurse#1', 'resident#140', 'aprn#1']
# ['lpn#4', 'mm']
# ['r#86', 'aide#2', 'person#2', 'resident#86', 'lpn#1', 'na#2', 'rn#4']
# ['resident#86']
# ['r#86', 'aide#2', 'person#2', 'resident#86', 'and#86', 'lpn#1', 'na#2', 'rn#4', 'resident#70']
# ['resident#86', "a. resident#70's", 'resident#70']
# ['r#86', 'aide#2', 'person#2', 'resident#86', 'lpn#1', 'worker#1', 'na#2']
# ['resident#86', 'worker#1']
# ['md#4', 'hospital#2', 'lpn#2', 'na#7', 'md#1', 'r#140', 'na#3', 'rn#1', 'na#12', 'lpn#12', 'resident#140', 'aprn#1', 'na#6', 'rn#4']
# ['timely.review', 'lpn#2', 'additionally na#6', 'redacted].c', 'na#6']
# ['resident#52', 'resident#82', 'lpn#5', 'resident#152']
# ["a. resident#52's", 'lpn#5', 'resident#82', 'resident#152']
# ['lpn#6', 'rn#5', 'rn#6', 'md#3', 'resident#133', 'resident#32', 'resident#12']
# ["c. resident#133's", 'notified.review', "b. resident#32's", 'a. resident#12']
# ['na#4', 'resident#140', 'rn#7', 'member#1', 'na#3', 'resident#58', 'representative#1']
# ['b. resident#140', 'resident#58', "a. resident#58's", 'walk.a']
# ['housekeeper#1']
# []
# ['resident#140']
# []
# ['r#128', 'na#1', 'lpn#2', 'sn#1', 'rn#128', 'na#2']
# ['na#1', 'lpn#2']
# ['r#128', 'na#1', 'lpn#2', 'rn#3', 'sn#1']
# []
# ['na#4', 'r#117']
# ['na#4']
# ['resident#59', 'r#59', 'resident#72']
# ["b. resident#59's", 'nurse', "a. resident#59's"]
# ['resident#143']
# []
# ['r#76']
# ['resident#76']
# ['resident#36', 'r#36', 'rn#1']
# []
# []
# []
# ['lpn#6', 'aprn#2', 'rn#1', 'lpn#5', 'md#2', 'resident#10', 'resident#57']
# ['lpn#5', 'resident#10', 'lpn)#5', 'aprn#2']
# ['resident#57', 'lpn#6', 'rn#1']
# []
# ['rn#6', 'lpn#2', 'resident#106']
# ['lpn#2']
# ['resident#86']
# ['resident#86', 'locomotion.a', 'redacted].resident#86']
# ['rn#3', 'lpn#7', 'resident#206', 'nurse#6', 'md#3', 'r#206', 'resident#10', 'r#306', 'na#10']
# ['resident#10', 'resident#206']
# ['rn#8', 'rn#7', 'resident#306', 'lpn#4', 'resident#104', 'r#306']
# ['lpn#4', 'don', '5/10/18']
# ['na#8', 'resident#19']
# []
# ['rn#3', 'rn#7', 'lpn#7', 'slp#2', 'slp#1', 'resident#500', 'lpn#2', 'resident#106', 'na#9', 'resident#206', 'md#3', 'resident#107', 'na#4', 'da#1', 'rn#6', 'lpn#3', 'na#10', 'lpn#8', 'na#3', 'na#12', 'na#2', 'rn#4']
# ['lpn#2', 'resident#206']
# []
# []
# ['na#11']
# []
# ['aide#4']
# []
# ['r#306', 'rn#1']
# []
# []
# []
# ['nurse#1']
# []
# ['resident#77', 'na#1', 'r#77']
# []
# ['r#61', 'dn#1', 'nurse#1', 'aprn#2', 'rn#1', 'resident#61', 'aprn#1', 'resident#93']
# ['foley catheter change']
# ['r#28', 'md#1', 'r#93', 'lpn#1', 'rn#1', 'rn#2', 'resident#93', 'resident#28']
# ['r#93']
# ['residents#63', 'resident#63']
# []
# ['rn#2', 'resident#93']
# []
# ['rn#1', 'resident#93']
# ['nurse']
# ['na#1', 'resident#1', 'lpn#1', 'rn#1']
# ['na#1', 'rn#1', 'cm']
# ['resident#79', 'lpn#1']
# []
# ['rooms#40', 'rooms#16', 'rooms#46', 'rooms#28', 'room#22', 'room#25', 'room#16', 'room#21']
# ['a. observations']
# ['resident#79', 'na#4', 'resident#40', 'rn#1', 'rn#2']
# ["a. resident#40's"]
# ['resident#26', 'rn#1']
# []
# ['resident#26', 'rn#1']
# []
# ['resident#29', 'lpn#2', 'rn#2']
# ['resident#29', 'lpn#2', 'redacted].physician']
# ['resident#16', 'lpn#1', 'rn#1']
# ['resident#16']
# []
# []
# ['housekeeper#1', 'resident#63']
# []
# ['resident#12', 'sw#1', 'rn#1']
# []
# ['resident#66']
# ['resident#66']
# ['aprn#1', 'resident#57', 'na#1']
# []
# ['aprn#1', 'resident#8', 'md#1']
# []
# ['and#71', 'resident#71', 'resident#27', 'residents#27']
# ['resident#71', 'resident#27', 'residents#27']
# ['lpn#2', 'resident#185', 'lpn#1', 'rn#2', 'person#1']
# ['lpn#2', 'mar']
# ['resident#38', 'rn#1']
# ['resident#38 re-', 'resident#38']
# ['manager#1', 'ot#1', 'na#1', 'resident#40']
# ['resident#40']
# ['resident#14', 'resident#40', 'lpn#1']
# ['resident#40']
# ['na#1', 'resident#154', 'na#2']
# []
# ['resident#183']
# []
# ['housekeeper#1', 'kitchenette#1']
# []
# ['resident#1', 'residents#1', 'and#41', 'resident#41']
# ['residents#1 and#41', 'resident#41']
# []
# ['a.', 'bin']
# ['housekeeper#1']
# []
# ['rn#3', 'resident#5', 'resident#1', 'and#7', 'rn#1', 'resident#2', 'residents#1', 'resident#4', 'resident#7', 'resident#3', 'rn#2', 'resident#6']
# ['resident#3']
# ['resident#2', 'hospital#1']
# []
# ['na#1', 'hospital#1', 'lpn#2', 'rn#3', 'person#2', 'na#2', 'resident#2', 'lpn#3', 'resident#3', 'person#1', 'rn#4']
# ['lpn#2', 'resident#3']
# ['hospital#2', 'na#4', 'resident#1', 'lpn#1', 'na#3', 'rn#1']
# ['na#4']
# ['resident#111', 'lpn#3', 'md#1', 'rn#2']
# ['p. m.']
# ['resident#17', 'resident#111']
# []
# ['resident#118', 'md#1', 'lpn#4', 'lpn#1', 'lpn#5']
# ['lpn#4']
# ['resident#118', 'md#1', 'pa#1', 'lpn#4', 'lpn#1', 'rn#1', 'lpn#5', 'resident#93']
# ['lpn#4', 'resident#93']
# ['cook#1', 'resident#111', 'md#1', 'resident#59', 'rn#1', 'and#59', 'aide#1', 'resident#63', 'lpn#3', 'resident#219', 'rn#2', 'rn#4']
# ['cr-cinnamon', 'strawberry', 'p. m.', 'resident#219']
# ['resident#11', 'resident#59', 'lpn#1', 'resident#149', 'resident#156']
# []
# ['resident#398', 'person#1']
# ['decisions.a']
# ['na#9', 'na#10', 'person#2', 'resident#70']
# ['resident#70']
# ['resident#15']
# ['resident#15']
# ['resident#5', 'resident#70']
# ['resident#70']
# ['na#5', 'na#4', 'resident#67', 'na#1', 'coordinator#1', 'lpn#3', 'aide#1', 'person#1', 'resident#6']
# ['resident#67']
# ['na#5', 'na#4', 'resident#67', 'na#1', 'coordinator#1', 'lpn#3', 'aide#1', 'person#1']
# ['resident#67']
# ['person#2', 'md#1', 'na#8', 'lpn#1', 'resident#29', 'na#6', 'resident#70']
# ['na#6', 'resident#70']
# ['resident#72', 'lpn#5']
# ['resident#72']
# ['resident#15']
# ['resident#15']
# ['person#2', 'md#1', 'na#8', 'lpn#1', 'resident#29', 'na#6', 'resident#70']
# ['na#6', 'resident#70']
# ['na#5', 'na#4']
# []
# ['resident#72']
# []
# ['lpn#4', 'resident#57']
# ['lpn#4']
# ['resident#6']
# []
# ['lpn#3', 'md#1', 'resident#3']
# ['resident#3', '1/8/18']
# ['lpn#2', 'rn#3', 'and#4', 'resident#1', 'na#3', 'resident#4', 'na#2']
# ['don', 'lpn#2', 'resident#4']
# ['rn#4', 'lpn#3', 'resident#3']
# ['resident#3']
# ['lpn#3', 'resident#3']
# ['resident#3']
# ['rn#4', 'lpn#5', 'lpn#3', 'resident#3']
# ['lpn#5', 'resident#3']
# ['and#6', 'na#3', 'rn#2', 'na#2', 'na#6']
# []
# ['rn#1']
# ['treatments.interview', 'resident#144']
# ['na#1', 'lpn#1', 'rn#2', 'therapist#1', 'r#63']
# ['therapist#1']
# ['worker#1']
# []
# ['sw#2', 'resident#1', 'lpn#1', 'sw#1']
# []
# ['r#42', 'rn#3', 'resident#42', 'rn#2', 'aprn#1', 'rn#4']
# []
# ['lpn#4', 'r#176', 'resident#176', 'cota#1']
# ['lpn#4']
# []
# []
# ['resident#254', 'lpn#1']
# ['foley catheter and/or', 'foley catheter']
# ['resident#86', 'lpn#1']
# ['resident#86', 'nurse', 'mar']
# ['lpn#1']
# []
# []
# []
# []
# []
# ['lpn#1', 'resident#78', 'na#2']
# []
# ['resident#86', 'aprn#1', 'resident#68']
# ['resident#86', 'resident#68']
# ['resident#78']
# []
# []
# []
# ['rn#4', 'resident#88', 'na#4', 'na#3']
# ['resident#88']
# ['na#1', 'resident#118']
# []
# ['na#4', 'aprn#1', 'resident#88', 'na#3', 'rn#2', 'rn#4', 'resident#28']
# ['resident#88']
# ['rn#4', 'resident#88', 'na#4', 'na#3']
# ['resident#88']
# ['resident#86', 'aprn#1', 'resident#68']
# ['resident#86', 'resident#68']
# []
# []
# ['resident#77', 'resident#64', 'resident#62', 'rn#6', 'rn#4']
# ['resident#77', 'resident#62']
# []
# ['needed.1']
# ['aprn#1', 'resident#1', 'rn#1']
# []
# ['r#12', 'and#112', 'na#4', 'lpn#2', 'resident#112', 'and#191', 'lpn#1', 'r#112', 'rn#2', 'r#78', 'resident#12', 'residents#186']
# ['resident#112', 'na#4', 'lpn#2', 'station1']
# ['resident#122', 'r#122', 'lpn#1', 'rn#2']
# []
# ['resident#98', 'na#1', 'r#98', 'rn#1']
# ['kick na#1']
# []
# []
# ['resident#13', 'resident#61', 'resident#74', 'resident#23']
# ['resident#13', 'resident#61']
# ['lpn#2']
# ['lpn#2', 'resident#70']
# ['r#229', 'r#61', 'rn#3', 'r#235', 'lpn#1', 'rn#1', 'resident#229', 'resident#61', 'resident#235']
# ['tracking.3', 'resident#229', 'resident#61']
# ['resident#24', 'r#235', 'resident#199', 'r#84', 'resident#', 'rn#1', 'r#199', 'resident#235']
# ['redacted].2', 'r#199', 'resident##84', 'r#235']
# []
# []
# ['r#229', 'r#61', 'lpn#1', 'rn#1', 'resident#229', 'resident#61']
# ['resident#229']
# ['rn#3']
# []
# ['lpn#1', 'resident#517']
# []
# ['resident#17', 'r#517', 'resident#517', 'rn#1']
# []
# ['aprn#1', 'resident#135', 'rn#1']
# []
# ['resident#1', 'rn#2', 'rn#1']
# ['don']
# ['resident#302', 'resident#300', 'person#1']
# []
# ['resident#302']
# []
# ['and#100', 'resident#8', 'lpn#1', 'resident#100']
# []
# ['resident#134']
# []
# ['resident#134']
# []
# ['resident#29', 'aprn#1', 'pharmacist#1', 'lpn#1']
# ['mar']
# ['dishwasher#1', 'cook#1']
# []
# ['resident#98', 'rn#1', 'resident#354', 'and#354']
# []
# ['r#359', 'lpn#2', 'mfd#1', 'md#1']
# ['lpn#2', 'nurse']
# []
# []
# ['na#1', 'lpn#2', 'resident#54']
# ['lpn#2', 'resident#54']
# ['r#8', 'na#2']
# []
# []
# ['redacted].resident#35']
# ['na#3']
# []
# ['resident#90', 'rn#3', 'r#20', 'resident#20', 'r#72', 'rn#1', 'person#1', 'rn#4']
# ['r#72', 'resident#20', 'resident#90']
# ['da#1', 'cook#1', 'resident#73', 'r#73']
# ['johnny coat', 'r#73']
# ['resident#73', 'r#73']
# ['resident#73', 'johnny coat', 'r#73']
# []
# ['b-16', 'b-20']
# ['r#79', 'resident#79', 'rn#1']
# ["b. r#79 '"]
# ['r#90', 'r#19', 'na#5', 'resident#90', 'lpn#2', 'resident#19']
# ["b. resident#90 ' s", 'lpn#2', 'a.']
# ['resident#90']
# ['mar']
# ['r#76', 'na#4', 'resident#76', 'rn#1']
# ['resident#76']
# ['resident#100']
# []
# ['resident#59', 'r#59', 'na#1', 'lpn#1']
# []
# ['resident#111', 'resident#20', 'lpn#1', 'resident#72', 'resident#63', 'na#2', 'rn#4']
# ['resident#20', 'nurse']
# []
# ['elbow macaroni', 'and/or yogurt']
# []
# ['mdro log']
# []
# ['b-16', 'b-20']
# []
# []
# ['resident#1', 'rn#1']
# []
# ['r#76', 'person#3', 'resident#76']
# ['resident#76']
# ['resident#85']
# []
# ['r#93', 'na#4', 'lpn#3', 'resident#93']
# []
# ['lpn#2', 'resident#85', 'person#2', 'sw#1', 'pt#1', 'resident#9', 'resident#66', 'resident#76', 'resident#37', 'r#37', 'worker#1', 'person#1', 'r#76', 'resident#8', 'r#9']
# ['lpn#2', 'resident#76', 'resident#66']
# ['housekeeper#1', 'resident#34', 'housekeeper#2']
# ['resident#34']
# ['lpn#2', 'resident#73', 'resident#66', 'rn#1', 'worker#1', 'resident#25', 'r#73']
# ['lpn#2', 'resident#66', 'max', 'worker#1', 'r#73']
# ['r#56', 'na#1', 'person#5', 'resident#78', 'cna#1', 'resident#5', 'r#36', 'person#3', 'resident#76', 'rn#1', 'resident#36', 'resident#7', 'resident#56', 'aide#1', 'r#76', 'r#78']
# ['zolpidem', 'resident#36', 'person#5', 'resident#76']
# ['rn#3', 'md#1', 'resident#88', 'rn#1', 'resident#7', 'r#37', 'resident#37', 'resident#61', 'r#88']
# ['resident#61', 'mar']
# ['cook#3', 'cook#2']
# ['cook#3', 'cook#2']
# ['lpn#4', 'nurse#1', 'rn#1', 'r#37', 'resident#37', 'worker#1']
# ['lpn#4']
# ['na#5', 'lpn#2', 'resident#66', 'rn#1']
# ['lpn#2', 'resident#66']
# ['r#76', 'person#3', 'resident#76']
# ['resident#76']
# ['worker#1', 'sw#1', 'resident#93']
# []
# ['resident#83', 'r#83', 'person#1']
# ['resident#83', 'r#83']
# ['housekeeper#1', 'resident#9', 'room#5', 'rooms#5', 'rn#1', 'rooms#19', 'rooms#2', 'lpn#3', 'room#3', 'room#6', 'rooms#3']
# []
# []
# []
# ['cook#1']
# ['debris.8']
# ['resident#83', 'r#83']
# ['resident#83', 'r#83']
# ['resident#14', 'lpn#2']
# ['lpn#2']
# ['resident#42']
# ['walk.a']
# ['resident#14', 'na#5', 'lpn#2', 'na#6', 'resident#49']
# ['lpn#2', 'na#6', 'redacted].resident#49']
# ['and#53', 'lpn#5']
# ['mar']
# ['na#5', 'lpn#2', 'na#6', 'resident#49']
# ['lpn#2', 'na#6', 'redacted].resident#49']
# ['resident#14', 'na#3']
# []
# ['lpn#4', 'rn#3', 'resident#52']
# ['lpn#4', 'resident#52']
# ['lpn#4', 'aide#1', 'na#4', 'resident#62']
# ['department.a', 'lpn#4', 'resident#62']
# ['cook#1']
# ['and/or designee']
# ['resident#8']
# []
# ['resident#11', 'and#58', 'resident#4', 'at#', 'rn#2', 'resident#58']
# ['resident#4', 'mar']
# []
# ['and/or designee']
# ['resident#59', 'person#1']
# []
# ['resident#146', 'md#1']
# []
# ['lpn#5', 'resident#103']
# []
# ['na#1', 'na#4', 'lpn#2', 'resident#24', 'bathroom#208']
# ['lpn#2']
# ['physician#2', 'resident#157', 'md#3', 'supervisor#1']
# ['resident#157']
# []
# []
# []
# []
# ['rn#3', 'rn#2']
# []
# []
# []
# ['na#1', 'na#3', 'rn#1', 'resident#2', 'resident#4', 'aide#1', 'rn#2', 'na#2', 'aprn#1']
# ['na#1']
# ['aprn#1', 'rn#1']
# []
# ['na#5', 'r#30', 'na#1', 'resident#120', 'r#129', 'lpn#1', 'na#3', 'resident#43', 'r#120', 'r#43', 'resident#30', 'na#2', 'resident#29', 'resident#129']
# ['resident#43', 'resident#30']
# ['resident#71', 'lpn#2']
# ['resident#71', 'lpn#2']
# ['resident#158', 'na#6']
# ['na#6']
# ['resident#115']
# []
# []
# ['jello container']
# ['resident#1', 'r#1', 'lpn#1', 'na#3']
# []
# ['na#1', 'na#3', 'na#2']
# []
# ['rn#2', 'resident#6']
# []
# ['na#1', 'resident#79']
# ['resident#79']
# ['resident#45', 'lpn#10']
# []
# ['assistedresident#45', 'resident#45', 'na#3', 'rn#1', 'and#45', 'resident#4', 'na#2', 'ot#1', 'na#10']
# ['resident#4', 'a. resident#4', 'residents#4 and#45']
# ['resident#238']
# []
# ['lpn#4', 'resident#6']
# ['lpn#4']
# ['rph#2', 'resident#6']
# []
# ['resident#65']
# ['resident#65']
# ['rn#1']
# []
# ['aid#2', 'person#1']
# []
# ['lpn#5', 'resident#65', 'resident#188']
# ["a. resident#65's", 'resident#65']
# ['lpn#2', 'lpn#1', 'rn#1', 'resident#37', 'rn#2']
# ['lpn#2']
# ['resident#43', 'resident#28']
# ['resident#43', 'a. resident#28']
# []
# ['resident#30']
# []
# ['resident#70']
# []
# ['resident#30']
# ['rn#1', 'resident#21', 'person#1']
# []
# ['na#1', 'rn#2', 'rn#1']
# []
# ['na#1', 'resident#1', 'na#2']
# ['bin', 'foley']
# ['resident#132', 'rn#2']
# ['dentures.review']
# ['rn#3', 'lpn#1', 'resident#154', 'rn#1', 'resident#53', 'resident#194', 'rn#5', 'rn#4']
# ['methicillin', "a. resident#53's"]
# ['resident#251', 'rn#1', 'md#1', 'person#1']
# []
# ['resident#1', 'resident#2', 'resident#4', 'worker#1', 'rn#2', 'resident#3']
# ['resident#4', 'worker#1', 'resident#3']
# ['rn#4', 'resident#38']
# ['resident#38']
# []
# []
# ['resident#118', 'lpn#1', 'staff#1', 'rn#2', 'na#2']
# ['staff#1', 'nurse']
# ['rn#4', 'resident#99', 'resident#115']
# ["b. resident#99's", 'a. interview', 'lobby and/or entrance', 'odor.resident#115', 'cm)', 'resident#99']
# []
# []
# ['rn#2', 'lpn#3', 'resident#37', 'md#1']
# []
# ['sw#2', 'resident#40', 'person#2']
# ['person#2']
# ['r#133', 'person#1']
# []
# ['aide#1']
# []
# ['rn#4', 'resident#236', 'na#2', 'rn#1']
# []
# ['resident#59', 'lpn#1']
# []
# ['resident#80', 'rn#4', 'areas#14']
# ['changes.a']
# ['personnel#1', 'resident#1', 'worker#1']
# []
# ['resident#1', 'rn#1', 'na#2']
# []
# ['resident#1', 'na#3', 'rn#1', 'na#2', 'personnel#1']
# []
# ['r#51', 'resident#51']
# ['dyskenesia', 'physician']
# ['r#31', 'resident#31']
# ['r#31', 'mar']
# ['r#31', 'resident#31']
# []
# ['r#31', 'resident#31', 'md#1']
# ['r#31', 'mar']
# ['r#51']
# ['physician']
# ['r#51', 'resident#51']
# ['physician', 'resident#51']
# []
# []
# ['resident#28']
# []
# ['resident#69', 'rn#5']
# ['resident#69']
# ['resident#28']
# []
# ['na#1', 'resident#16', 'na#2']
# ['resident#16']
# ['resident#35', 'resident#69', 'resident#5', 'lpn#1', 'rn#1', 'rn#2', 'and#69', 'residents#5', 'resident#13']
# ['resident#69', 'resident#13']
# ['na#1', 'na#5', 'resident#24', 'resident#51', 'resident#33', 'na#3', 'otr#1', 'person#1', 'lpn#10', 'resident#3', 'na#2', 'lpn#11', 'resident#10']
# ['resident#10', 'resident#24', 'resident#3']
# ['resident#24']
# []
# ['resident#22', 'hk#1', 'resident#44']
# ['resident#22']
# ['rn#3', 'md#1', 'dietician#2', 'resident#243', 'dietician#1']
# ['dietician#2']
# ['resident#98', 'na#1', 'resident#252', 'resident#140', 'resident#38', 'resident#78', 'resident#105', 'resident#423', 'resident#259', 'lpn#1', 'rn#1', 'resident#2', 'resident#17', 'resident#16', 'resident#287', 'resident#219', 'resident#293']
# ["b. resident#252's", 'resident#38, resident#78', "a. resident#423's"]
# ['rn#5', 'resident#311']
# []
# ['mw#1', 'worker#1']
# ['mw#1', 'worker#1']
# ['resident#243', 'dietician#2', 'dietician#1']
# ['dietician#2']
# []
# []
# ['person#2', 'staff#2', 'resident#251', 'staff#1', 'resident#261']
# ['staff#2']
# ['na#1', 'resident#97', 'na#3', 'rn#1', 'na#2', 'resident#176']
# ['b. na#2', 'a. observation', 'c. na#2']
# []
# ['brown']
# ['staff#3']
# ['puree vegetable140 f rice']
# ['staff#1', 'staff#3', 'staff#2']
# ['staff#2']
# []
# []
# ['na#1', 'na#4', 'na#7', 'resident#1', 'lpn#1', 'na#3', 'rn#1', 'na#2', 'na#8']
# ['na#3']
# ['na#5', 'resident#1', 'person#1']
# ['don']
# ['na#1', 'na#4', 'na#7', 'resident#1', 'lpn#1', 'na#3', 'rn#1', 'na#2', 'na#6', 'na#8']
# ['na#6']
# ['md#1']
# []
# ['na#1', 'na#7', 'resident#1', 'nurse#1', 'lpn#1', 'na#3', 'na#6', 'na#8']
# ['c.', 'nurse#1', 'na#3', 'na#6', 'redacted].resident#1']
# []
# []
# []
# []
# ['resident#34', 'rn#1']
# ['resident#34']
# ['resident#38', 'supervisor#1']
# ['resident#38']
# ['lpn#2', 'rn#3', 'st#1', 'na#2', 'resident#60']
# ['foley', 'lpn#2', 'resident#60']
# ['rn#1']
# ['cm']
# ['resident#39']
# []
# ['resident#127']
# []
# ['na#1', 'lpn#2', 'md#1', 'resident#157', 'lpn#1', 'lpn#3']
# ['resident#157', 'lpn#2']
# ['resident#69', 'consultant#1']
# ['resident#69', "a. resident#69's", "b. resident#69's"]
# ['resident#65', 'lpn#1']
# ['resident#65']
# ['resident#9', 'resident#113', 'md#1', 'rn#1']
# ['b.', 'a.']
# ['md#1', 'lpn#4', 'nurse#1', 'rn#6', 'resident#133', 'na#6']
# ['lpn#4', 'na#6']
# ['resident#27', 'lpn#1', 'rn#1']
# ['resident#27']
# ['rn#7', 'na#9', 'nurse#1', 'cota#1', 'rn#1', 'rn#5', 'resident#149', 'resident#23', 'na#2', 'na#8']
# ['resident#23']
# ['da#2', 'aide#2', 'na#9', 'cota#1', 'rn#1', 'rn#5', 'da#1', 'resident#149', 'resident#23', 'aide#1', 'na#2', 'resident#80', 'na#8']
# ['resident#23']
# ['rn#7', 'cota#1', 'rn#1', 'resident#23', 'na#2']
# ['resident#23']
# ['facility#1', 'nurse#1', 'resident#136', 'md#1']
# []
# ['md#1', 'lpn#4', 'nurse#1', 'rn#6', 'resident#133', 'na#6']
# ['lpn#4', 'na#6']
# ['rn#3', 'md#1', 'resident#55', 'nurse#1', 'lpn#3', 'rn#4', 'resident#12']
# ['resident#55']
# ['nurse#1', 'resident#136', 'md#1']
# []
# ['na#1', 'resident#27', 'lpn#1']
# ['resident#27']
# ['da#1', 'da#2', 'aide#1', 'aide#2']
# []
# ['na#1', 'md#1', 'resident#1', 'lpn#1', 'rn#1', 'resident#4', 'r#1']
# ['don', 'lpn#1']
# ['md#1', 'resident#1', 'lpn#1', 'r#1', 'and#3', 'resident#3']
# ['don', 'mar', 'lpn#1', 'resident#3']
# ['na#1', 'resident#4', 'md#1', 'rn#1']
# []
# ['resident#5', 'na#1', 'lpn#1', 'na#2']
# ["a. resident#5's"]
# ['and#306', 'resident#306', 'md#1', 'resident#309', 'resident#29', 'rn#4']
# ['resident#29', "a. resident#29's"]
# ['resident#43', 'md#1']
# ['resident#43', 'redacted].resident#43']
# ['resident#5']
# []
# []
# []
# ['rn#1']
# ['a. interview']
# ['r#36', 'rn#3', 'rn#1']
# []
# []
# []
# []
# []
# ['r#24', 'r#12', 'r#49', 'r#40', 'r#47']
# []
# ['na#4', 'r#8', 'resident#40', 'lpn#1', 'lpn#3', 'r#40', 'resident#8', 'na#6']
# ['na#6']
# ['lpn#2', 'resident#40']
# ['lpn#2']
# ['r#19', 'rn#1', 'r#13', 'lpn#3', 'ot#1', 'resident#13', 'resident#19']
# ['resident#13']
# ['lpn#3', 'lpn#1', 'rn#2', 'rn#1']
# []
# ['r#31', 'housekeeper#1', 'r#33', 'resident#33', 'lpn#1', 'resident#31', 'na#3', 'rn#2']
# ['c.', 'a.', "adl's.a physician's"]
# ['resident#9', 'rn#1']
# []
# ['resident#2']
# []
# ['lpn#4', 'resident#36', 'rn#2']
# ['lpn#4', 'resident#36', 'condition]-']
# ['na#1', 'r#99', 'rn#3', 'na#3', 'rn#5', 'rn#2', 'person#1', 'resident#99']
# ['r#99']
# ['aprn#1', 'resident#71']
# ['resident#71']
# []
# []
# ['rn#5', 'rn#4', 'lpn#3']
# []
# ['rn#1']
# ['commode', 'bin']
# ['person#1']
# []
# ['resident#1', 'worker#1']
# []
# ['aprn#1', 'resident#1', 'md#1']
# []
# ['person#4', 'na#1', 'resident#1', 'resident#3']
# ['na#1', 'resident#3']
# ['lpn#1', 'resident#6', 'rn#1']
# ['don', 'discard and/or', 'lpn#1']
# ['na#4', 'na#3', 'resident#4', 'lpn#3', 'rn#2']
# ['don', 'resident#4']
# ['person#6', 'lpn#1', 'rn#1', 'na#6', 'resident#6']
# ['don', 'discard and/or', 'lpn#1', 'na#6']
# ['resident#2']
# []
# ['resident#2', 'resident#1', 'and#2']
# ['don']
# ['na#1', 'na#4', 'resident#40', 'na#3', 'rn#1', 'r#40']
# []
# ['r#56', 'na#1', 'na#4', 'lpn#2', 'resident#40', 'lpn#1', 'na#3', 'rn#1', 'resident#56', 'r#40']
# ['lpn#2']
# ['na#1', 'na#4', 'resident#35', 'rn#3', 'r#66', 'resident#40', 'r#8', 'na#3', 'rn#1', 'rn#5', 'rn#6', 'resident#66', 'resident#4', 'r#40', 'resident#8', 'na#6']
# ['visits.a', 'r#8', 'don', 'resident#4', 'na#6']
# ['rn#5', 'rn#6', 'resident#8', 'r#8']
# ['r#8']
# []
# []
# ['resident#44', 'na#2', 'rn#1', 'person#1']
# []
# ['rn#3', 'resident#40', 'resident#21', 'rn#1', 'aprn#1']
# []
# ['na#1', 'resident#56', 'rn#1']
# ['resident#56']
# ['aprn#1', 'resident#21', 'rn#1']
# []
# ['resident#91', 'rn#3', 'lpn#1', 'rn#1']
# ['c.', 'resident#91']
# ['rn#2', 'resident#54']
# []
# ['na#1', 'rn#3', 'resident#1', 'aprn#2', 'rn#1', 'rn#2', 'rd#1']
# ['don designee', '3/9/18', 'aprn#2', 'rivaroxaban.a', 'rd#1']
# ['rn#4', 'resident#4', 'resident#23']
# ['resident#23']
# ['na#4', 'rn#3', 'na#3', 'na#2', 'resident#6']
# []
# ['lpn#1', 'resident#51', 'person#1']
# ['don', 'resident#51']
# ['resident#47']
# ['resident#47']
# ['resident#47', 'lpn#1', 'rn#4']
# ['resident#47']
# ['resident#23']
# []
# ['resident#94', 'rn#1']
# ['resident#94']
# ['rn#3', 'r#27', 'resident#1', 'r#1', 'resident#27']
# ['resident#27']
# ['resident#94']
# ['resident#94']
# ['residents#17', 'resident#45', 'r#84', 'r#101', 'resident#84', 'resident#101', 'resident#17', 'r#45']
# ['resident#84', 'residents#17', 'resident#45', 'resident#101']
# ['na#1', 'resident#1', 'na#2']
# []
# ['resident#4', 'rn#3', 'resident#3']
# ['don', 'resident#3']
# []
# []
# ['person#5', 'r#27']
# ['resident#27', 'r#27']
# ['pa#1', 'pt#1', 'resident#87', 'person#1', 'assistant#1']
# ['nurse']
# []
# []
# []
# []
# ['r#24', 'resident#64', 'rn#3', 'resident#24', 'resident#51', 'resident#27', 'person#1']
# ['nectar', 'resident#27', 'resident#51']
# ['rn#3', 'pt#1', 'pa#1', 'resident#87', 'person#1']
# ['nurse']
# ['na#1', 'r#75', 'na#2']
# ['resident#75', 'r#75']
# ['person#3', 'r#75']
# ['resident#75']
# ['resident#77', 'resident#27', 'rn#3', 'r#77']
# ['resident#27']
# ['r#79', 'rn#4', 'resident#79', 'na#4']
# ['resident#79']
# ['rn#5', 'r#75']
# ['don', 'resident#75', 'r#75']
# []
# []
# ['r#38']
# ['resident#75']
# ['na#1', 'na#2', 'r#75']
# ['resident#75']
# ['room#4', 'room#9']
# []
# ['resident#97', 'rn#5', 'r#97', 'resident#75', 'r#75', 'rn#4']
# ['resident#75', 'r#75']
# ['resident#2']
# ['don', 'johnny']
# ['worker#1', 'sw#1', 'resident#54']
# ['worker#1', 'resident#54']
# ['resident#35', 'rn#3', 'rn#2', 'resident#54']
# ['resident#54']
# ['resident#64', 'resident#117', 'rn#1']
# []
# ['worker#1', 'resident#216']
# []
# ['na#1', 'lpn#6', 'receptionist#1', 'resident#54', 'lpn#4', 'lpn#1', 'resident#17', 'person#1', 'lpn#3', 'resident#216', 'aprn#1']
# ['lpn#4', 'na#1', "a. resident#17's", 'resident#54']
# ['resident#53', 'r#53', 'resident#42']
# ['resident#42']
# ['rn#1']
# []
# ['na#2', 'resident#21', 'na#3', 'resident#23', 'resident#29', 'and#29']
# ["a. resident#21's", 'resident#29', "b. resident#23's", 'resident#23']
# ['na#1', 'resident#55', 'na#3', 'na#2']
# []
# ['na#1', 'resident#55', 'na#3', 'na#2']
# []
# ['resident#1', 'residents#2', 'resident#2', 'resident#4', 'resident#3', 'person#1', 'and#3', 'and#2']
# ['resident#3']
# ['sw#1', 'resident#1', 'resident#2', 'resident#4', 'resident#3', 'person#1', 'and#3']
# ['resident#3']
# ['sw#1', 'resident#1', 'resident#2', 'resident#3', 'person#1']
# ['resident#3']
# ['resident#2', 'resident#1', 'resident#3', 'person#1']
# ['resident#3']
# ['r#5', 'sw#1', 'and#5', 'resident#5', 'resident#1', 'resident#2', 'resident#4', 'resident#3', 'person#1']
# ['resident#3']
# ['resident#26', 'and#87', 'resident#87', 'worker#1', 'residents#26']
# []
# ['resident#152']
# []
# ['resident#56']
# ['resident#56']
# ['lpn#9', 'rn#1', 'resident#154', 'na#10']
# []
# ['resident#184', 'lpn#1']
# ['resident#184s']
# ['resident#81', 'supervisor#1']
# ['resident#81']
# ['lpn#2', 'lpn#1', 'resident#81']
# ['resident#81']
# ['resident#159', 'rd#2', 'lpn#3', 'lpn#1']
# []
# ['resident#81', 'supervisor#1']
# ['resident#81']
# ['na#1', 'resident#1']
# []
# ['ot#1', 'resident#1', 'lpn#1', 'na#2']
# []
# ['r#2', 'resident#2', 'md#1']
# ['mar']
# ['sw#2', 'sw#1', 'secretary#1', 'resident#1', 'lpn#1', 'r#1', 'person#1']
# []
# ['r#2', 'resident#2', 'lpn#2', 'rn#1']
# ['g.', 'c.', 'lpn#2', 'mar']
# ['na#1']
# []
# ['na#3', 'rn#1', 'coordinator#1', 'person#58', 'person#10', 'resident#58', 'person#8', 'person#9']
# ['person#8', 'person#10', 'resident#58', '1/8/18']
# ['resident#104', 'trs#1']
# []
# ['lpn#6', 'lpn#4', 'rn#6', 'lpn#5', 'resident#63', 'lpn#3', 'resident#58']
# ['a. review', 'lpn#4', 'mar', 'resident#63', 'c. subsequently']
# ['resident#62', 'rn#6', 'lpn#3', 'resident#63', 'r#63', 'rn#4']
# ['resident#63', 'residents#62', 'resident#62']
# ['na#1', 'resident#1']
# []
# ['na#1', 'resident#104']
# []
# ['aprn#1', 'resident#125', 'md#1']
# []
# ['md#1', 'resident#125', 'and#125', 'resident#58', 'aprn#1']
# []
# ['lpn#1', 'resident#136']
# []
# ['resident#123', 'resident#118', 'lpn#2', 'resident#92', 'lpn#1', 'na#3', 'rn#1', 'rn#2', 'na#2', 'resident#29']
# ['lpn#2', 'resident#92', '1/8/18', 'redacted].c', 'resident#29']
# ['aprn#2', 'lpn#3', 'resident#3', 'na#8']
# ['don', 'aprn#2', 'resident#3']
# ['resident#1', 'lpn#2', 'rn#1']
# ['lpn#2']
# ['rn#1', 'person#1']
# []
# ['na#1', 'rn#2', 'rn#1']
# []
# ['lpn#1', 'resident#181']
# ['mar']
# ['aprn#1', 'resident#4']
# []
# ['resident#1']
# []
# ['resident#2', 'person#1']
# ['don']
# ['housekeeper#1', 'room#343', 'rn#1']
# []
# ['cook#1', 'cook#2']
# []
# ['aprn#4', 'rn#8', 'aprn#1', 'person#6', 'person#7', 'resident#113', 'resident#149', 'resident#81', 'lpn#3', 'rn#11', 'resident#168', 'rn#14', 'resident#150']
# ['don', 'and/or hematoma', 'resident#81']
# ['resident#423', 'person#10', 'worker#1', 'sw#1']
# ['worker#1']
# ['rn#1', 'person#1', 'na#1', 'lpn#2', 'resident#122', 'resident#60', 'na#4', 'resident#95', 'rn#5', 'rn#6', 'and#142', 'resident#123', 'resident#142', 'na#3', 'resident#53', 'rn#2', 'na#2', 'rn#10', 'rn#4']
# ['na#1', 'lpn#2', 'resident#95', 'don', 'resident#60']
# ['and#122', 'na#2']
# []
# ['na#1', 'resident#123', 'na#4', 'and#123', 'resident#122', 'rn#1', 'rn#6', 'person#1', 'rn#2', 'na#2', 'resident#60', 'na#10']
# ['don', 'na#1', 'resident#60']
# ['resident#423', 'person#10']
# []
# ['aprn#4', 'na#7', 'na#8', 'aprn#1', 'lpn#7', 'person#3', 'rn#14', 'resident#424', 'resident#113', 'resident#150', 'resident#81', 'rn#11', 'na#6', 'resident#25', 'na#10']
# ['resident#424', 'don', 'emar', 'resident#81', 'na#6']
# ['rn#8', 'na#5', 'lpn#5', 'resident#144']
# ['lpn#5', 'resident#144']
# ['resident#69', 'rn#12', 'rn#13']
# ['p. m.', 'resident#69', 'dns', 'rn#13']
# ['resident#5', 'rn#3', 'person#2', 'rn#7']
# []
# ['lpn#4', 'resident#9', 'resident#169']
# ['lpn#4', 'included:1.resident#169']
# ['aide#3', 'na#3']
# []
# ['resident#132', 'aprn#2']
# []
# ['lpn#4', 'resident#9']
# ['lpn#4']
# []
# []
# ['rn#8', 'resident#202']
# []
# ['resident#1']
# []
# ['resident#2', 'lpn#3', 'na#3']
# ['don']
# ['resident#22', 'na#1', 'lpn#1']
# ['resident#22', 'hunt(a', 'nurse']
# ['lpn#2', 'resident#56', 'md#1']
# ['lpn#2', 'resident#56']
# ['r#48', 'na#1', 'rn#3', 'resident#48']
# []
# ['resident#22', 'na#1', 'r#22', 'resident#9', 'lpn#1', 'rn#1', 'r#13', 'na#2', 'resident#13', 'resident#15', 'r#9']
# ['resident#22', 'r#13', 'hunt(a', "a. resident#9 '", 'resident#13', 'resident#15']
# ['r#37', 'na#4', 'resident#37']
# []
# ['na#5', 'na#6', 'r#58']
# ['na#6']
# ['na#5', 'na#6', 'rn#2', 'r#58']
# ['na#6']
# ['r#31', 'na#1', 'r#46', 'r#27', 'resident#31', 'na#3', 'rn#1', 'resident#46', 'resident#27', 'na#2']
# ['r#31', 'resident#27', 'r#27 rang', 'r#27']
# ['r#57', 'resident#14', 'resident#5', 'resident#9', 'lpn#1', 'resident#21', 'resident#41', 'resident#27', 'md#2', 'resident#61', 'resident#23', 'resident#18', 'resident#8', 'resident#57', 'and#61']
# ['8:00 pm.g', "a. resident#5's", 'resident#41', 'resident#27', 'md#2', 'resident#61', 'resident#23']
# ['aide#1', 'lpn#1']
# []
# ['r#31', 'r#12', 'r#17', 'rn#1', 'resident#53', 'resident#17', 'resident#12', 'r#53']
# ['don', 'r#31']
# ['lpn#2', 'lpn#1', 'resident#37', 'lpn#3', 'na#2', 'aprn#1']
# ['lpn#2']
# ['resident#37', 'lpn#1', 'na#2']
# []
# ['housekeeper#1', 'resident#31']
# []
# ['resident#18', 'rn#2']
# []
# ['na#5', 'na#1', 'na#3', 'rn#1', 'rn#2']
# ['c. interview']
# ['resident#18', 'md#1', 'rn#2']
# []
# ['r#102', 'na#1', 'resident#102', 'rn#1']
# ['rn#1']
# ['resident#19']
# []
# ['resident#69', 'na#3', 'r#69', 'na#2', 'resident#57']
# ['resident#69']
# ['r#19', 'lpn#1', 'na#2', 'rna#1', 'resident#19']
# []
# ['resident#22', 'resident#39', 'rn#1', 'resident#2', 'rn#2', 'resident#96']
# ['dessert', 'resident#96']
# ['resident#39', 'rn#1']
# []
# ['resident#1', 'person#1']
# []
# ['resident#1', 'lpn#3', 'person#1']
# []
# ['resident#1']
# []
# ['resident#33', 'rn#1']
# ['cm']
# ['resident#47', 'cannula#6', 'rn#1']
# ['resident#47']
# ['resident#34', 'rn#2', 'rn#1']
# ['resident#34']
# ['resident#14', 'na#2', 'person#1']
# []
# ['a#6', 'resident#47', 'cannula#6', 'lpn#1']
# ['resident#47']
# ['with#11', 'on#12', 'for#11', 'and#11', 'resident#23', 'rn#4']
# ['jaw and/or', 'mar']
# ['rn#1', 'resident#46']
# []
# ['resident#10', 'lpn#1', 'md#1']
# ['don', 'resident#10']
# ['resident#5', 'person#1']
# []
# ['resident#10']
# ['don', 'resident#10', 'nurse']
# ['resident#1', 'resident#10', 'md#1']
# ['resident#10']
# ['na#5', 'lpn#2', 'md#1', 'lpn#1', 'rn#1', 'resident#10', 'na#6']
# ['lpn#2', 'nurse', "a. nurse's", 'don', 'resident#10', 'na#6']
# ['lpn#3', 'resident#21', 'rn#1']
# ['redacted].resident#21']
# ['lpn#2', 'rn#3', 'resident#54', 'resident#525', 'resident#21', 'lpn#1', 'rn#1', 'rn#2', 'rn#4']
# ['lpn#2', 'resident#54']
# ['rn#1', 'resident#21', 'rn#2', 'resident#525']
# []
# ['rn#1', 'resident#21', 'rn#2', 'resident#525']
# []
# ['rn#1', 'resident#21', 'rn#2', 'resident#525']
# []
# ['lpn#2', 'rn#3', 'resident#54', 'lpn#1', 'rn#4']
# ['lpn#2', 'resident#54']
# ['resident#14']
# []
# ['na#1', 'resident#64', 'lpn#2', 'rn#1', 'rd#1', 'na#2']
# ['lpn#2', 'rd#1 further']
# ['resident#21', 'rn#2', 'resident#525']
# []
# ['rn#1']
# []
# ['resident#393']
# []
# ['rn#3', 'r#116', 'na#3', 'resident#165', 'resident#116', 'r#393', 'rn#2', 'resident#393', 'resident#108', 'r#165', 'r#150', 'resident#150']
# ['combative.interview']
# []
# []
# ['rn#5', 'r#167', 'resident#167']
# []
# ['resident#85']
# []
# ['na#1', 'rn#1', 'resident#143', 'person#1', 'ot#1', 'r#143']
# []
# ['na#1', 'rn#1', 'resident#143', 'person#1', 'ot#1', 'r#143']
# []
# ['resident#393']
# []
# ['na#1', 'resident#371', 'rn#3', 'rn#2']
# ['na#1']
# ['aprn#1', 'resident#213', 'aide#1', 'rn#1']
# ['monthly.interview', 'mm']
# ['resident#377']
# []
# ['rn#5', 'resident#158']
# []
# ['resident#377']
# []
# ['rn#5', 'na#1', 'resident#170']
# ['na#1']
# ['rn#5', 'na#1', 'resident#170']
# ['na#1']
# ['rn#2', 'resident#75']
# ['resident#75']
# ['resident#155', 'rn#6', 'rn#3', 'ot#1']
# []
# []
# ['c. three']
# []
# []
# ['resident#271', 'na#5', 'na#1', 'na#3', 'rn#2', 'na#2']
# []
# ['rn#6', 'resident#551', 'na#6', 'na#7']
# ['na#6']
# ['na#7', 'rn#7', 'resident#249', 'rn#10', 'na#8']
# []
# ['rn#7', 'lpn#7', 'rn#12', 'resident#115', 'rn#4', 'resident#13']
# ['include:1.resident#115', 'resident#13']
# ['rn#6', 'resident#551', 'na#6', 'na#7']
# ['na#6']
# ['refrigerator#19', 'microwave#2', 'freezer#12', 'wooster#4', 'sturges#4', 'warmer#1', 'and#17', 'refrigerator#10', 'warmer#3']
# ['kitchen.2', 'dark brown']
# ['lpn#6', 'rn#7', 'rn#9', 'ramage#5', 'lpn#5']
# ['lpn#5', 'lpn)#5']
# ['rn#5', 'rn#4', 'lpn#2']
# ['resident#13', 'lpn#2']
# []
# []
# ['resident#271', 'resident#551', 'rn#6', 'rn#2']
# ['don', 'resident#551']
# ['resident#1', 'md#2', 'rn#1']
# ['hydrogel', 'mm', 'rn#1', 'cm']
# ['resident#1', 'md#2']
# ['don']
# ['resident#1', 'md#2']
# []
# ['resident#1', 'rn#2']
# []
# ['resident#1', 'rn#1', 'md#2', 'rn#2', 'person#1']
# ['don', 'hydrogel', 'mm', 'cm']
# ['resident#1']
# ['don']
# ['resident#1', 'md#2', 'lpn#1', 'md#1']
# ['don']
# ['resident#798', 'rn#1']
# ['resident#798']
# ['resident#798']
# ['resident#798', 'don']
# ['lpn#2', 'resident#316', 'na#2']
# ['lpn#2']
# ['resident#24', 'and#245', 'resident#245', 'dietitian#1', 'lpn#1', 'aprn#1']
# ["a. resident#24's", "b. resident#245's"]
# ['resident#798', 'rn#3', 'resident#337']
# ["a. resident#337's", 'resident#798']
# ['rn#3', 'resident#337']
# []
# ['secretary#1', 'resident#104']
# []
# ['resident#316']
# []
# ['resident#4', 'rn#2', 'rn#1']
# []
# ['resident#2', 'lpn#3']
# []
# ['rn#2', 'rn#1']
# []
# ['lpn#1']
# ['lpn#1']
# ['aide#1', 'na#1', 'resident#163', 'rn#1']
# ['jesus christ', 'na#1.an']
# ['worker#2', 'resident#215', 'aprn#2']
# []
# ['rn#6', 'resident#692', 'aprn#3', 'lpn#2']
# ['resident#692', 'lpn#2', 'mar']
# ['aprn#1', 'resident#300', 'lpn#1']
# ['resident#300']
# []
# []
# ['resident#118', 'lpn#3', 'na#8']
# []
# ['resident#153']
# []
# ['aide#1']
# []
# ['resident#127']
# []
# ['na#1', 'resident#69', 'resident#163', 'lpn#1', 'resident#40', 'rn#1', 'rn#5', 'rn#6', 'resident#115']
# ['resident#40', 'resident#69', 'a.', 'resident#115']
# ['na#5', 'na#4', 'na#7', 'na#3', 'na#2', 'na#6']
# ['c.']
# ['housekeeper#1', 'person#4', 'resident#100']
# ['person#4']
# ['housekeeper#1', 'person#4', 'na#9', 'resident#100', 'rn#13']
# ['person#4', 'rn#13']
# ['resident#5', 'aprn#1']
# []
# ['resident#4']
# ['mar']
# ['resident#2', 'lpn#5', 'resident#3', 'and#3']
# ['lpn#5', 'lpn)#5', 'resident#3']
# ['na#1', 'resident#5', 'and#6', 'lpn#8', 'resident#4', 'na#2', 'resident#6']
# ['don', 'na#1']
# ['resident#5', 'aprn#1']
# []
# ['resident#5']
# ['mar']
# ['and#5', 'aide#1']
# ['don']
# ['rn#3', 'resident#5', 'and#6', 'rn#5', 'aprn#1', 'resident#6']
# ['don', 'lpn)#5']
# ['and#5', 'resident#5', 'resident#1', 'resident#3']
# ['resident#3']
# ['lpn#1', 'resident#30']
# ['resident#83', 'resident#30']
# ['lpn#5', 'lpn#2', 'lpn#3', 'resident#38']
# ['lpn#2', 'resident#38', 'activity.b', 'lpn#5', "a. resident#38's"]
# []
# []
# ['resident#3']
# ['resident#3']
# ['person#2', 'resident#1', 'r#6', 'lpn#1', 'r#1', 'resident#6']
# ['don', 'admission).review', 'review.b']
# ['resident#1']
# ['don']
# ['resident#1', 'r#1', 'rn#1']
# ['don']
# ['na#5', 'r#4', 'rn#1']
# ['a. r#4 [', 'revised.b']
# ['r#4', 'lpn#2', 'na#3', 'person#1']
# ['lpn#2']
# ['r#2', 'resident#2', 'lpn#3', 'rn#1']
# ['foley', 'foley catheter']
# ['r#2', 'resident#2']
# ['don', 'mar', '4/9/18']
# ['r#5', 'resident#1', 'nurse#1', 'lpn#1', 'rn#1', 'physician#1', 'r#1']
# ['don', 'a.']
# ['lpn#2', 'resident#38', 'md#1', 'resident#1', 'lpn#1', 'rn#1', 'rn#2']
# ['lpn#2', 'b. resident#38', 'resident#38', 'abd pad']
# ['resident#38', 'rn#1']
# ['resident#38']
# ['na#1', 'lpn#4', 'na#3', 'rn#1', 'resident#7', 'lpn#3', 'resident#8', 'and#8']
# ['lpn#4', 'resident#7']
# ['rn#3', 'resident#49', 'na#2']
# ['matt']
# ['resident#23']
# ['redacted].resident#23']
# ['t#54', 'resident#54']
# ['a.', 'resident#54']
# ['lpn#5', 'lpn#6', 'lpn#3']
# []
# ['rn#1', 'resident#23']
# ['redacted].resident#23', 'resident#23']
# ['na#1', 'na#4', 'r#25', 'resident#41', 'na#2', 'r#41', 'resident#25']
# ['r#41', 'resident#41']
# ['na#4', 'r#25', 'resident#41', 'na#2', 'r#41', 'resident#25']
# ['r#41', 'resident#41']
# ['na#4', 'r#25', 'resident#41', 'na#2', 'r#41', 'resident#25']
# ['r#41', 'resident#41']
# ['cook#2']
# []
# ['lpn#2', 'cook#1', 'r#18', 'r#25', 'resident#74', 'r#74', 'na#3', 'resident#18', 'resident#25']
# ['lpn#2']
# ['resident#318', 'na#2']
# ['resident#318']
# ['rn#1', 'resident#61', 'resident#58']
# ['resident#61']
# ['rn#1', 'resident#58']
# []
# ['tooth#6', 'person#4', 'person#2', 'sw#1', 'and#27', 'person#3', 'resident#21', 'resident#66', 'teeth#26', 'upper#6', 'and#14', 'dentist#1', 'tooth#27', 'person#1', 'aprn#1', 'lower#26', 'tooth#26']
# ['teeth#26 and#27', 'taylor', 'cm', 'resident#66', 'lower#26 and#27']
# ['resident#62', 'lpn#1', 'rn#1']
# ['resident#62']
# ['tooth#6', 'and#27', 'teeth#26', 'upper#6', 'resident#66', 'and#14', 'dentist#1', 'tooth#27', 'aprn#1', 'lower#26', 'tooth#26']
# ['teeth#26 and#27', 'lower#26 and#27', 'resident#66']
# ['resident#21', 'employee#1', 'resident#54']
# []
# ['employee#1']
# []
# ['resident#44']
# []
# ['resident#44']
# []
# ['rn#1', 'resident#9', 'resident#54']
# []
# ['resident#29', 'lpn#5']
# ['resident#29', 'changes.interview']
# ['resident#7']
# []
# ['r#19', 'r#116', 'lpn#1', 'resident#19']
# []
# ['lpn#2', 'rn#3', 'resident#96']
# ['resident#96']
# ['lpn#1', 'r#116', 'resident#116', 'r#19']
# []
# []
# []
# ['resident#71', 'resident#7', 'rn#2']
# ['resident#71']
# ['resident#140']
# []
# ['lpn#2', 'rn#3', 'lpn#1', 'r#96', 'resident#58', 'resident#96']
# ['lpn#2', 'resident#96']
# ['resident#71', 'lpn#1', 'rn#2', 'rn#1']
# ['resident#71', 'mar']
# []
# []
# []
# []
# ['resident#71', 'lpn#1', 'rn#2', 'rn#1']
# ['resident#71']
# ['housekeeper#1', 'na#1', 'r#1', 'rn#2', 'na#6']
# ['na#6']
# ['r#5', 'rn#1']
# []
# ['na#4', 'r#5', 'resident#5', 'rn#1', 'resident#2', 'md#3']
# []
# ['resident#77', 'lpn#2', 'rn#1', 'r#70', 'r#77', 'resident#70']
# []
# ['na#1', 'na#2', 'na#3', 'rn#1', 'r#13', 'r#111', 'aide#1', 'resident#75', 'r#75']
# ['na#3', 'resident#75']
# []
# []
# ['na#5', 'resident#64', 'na#4', 'r#64', 'lpn#1', 'aide#4', 'rn#2', 'rn#4', 'aide#5']
# ['aide#5']
# ['r#158', 'na#7', 'rn#6', 'resident#158', 'na#6']
# ['na#6']
# []
# ['debris.8']
# ['na#1', 'resident#73', 'lpn#1', 'rn#1', 'na#2', 'r#73']
# ['resident#73', 'r#73']
# ['resident#10']
# []
# ['na#5', 'na#4', 'resident#92', 'na#3', 'resident#72', 'resident#371', 'rn#4']
# ['resident#72', 'resident#92']
# ['na#4', 'lpn#3', 'resident#37']
# []
# ['na#4', 'lpn#3', 'resident#37']
# []
# ['na#1', 'aide#1']
# []
# ['staff#1', 'staff#2']
# ['dietary staff#2', 'staff#2']
# ['rn#3']
# ['ppsv23', 'acip']
# ['resident#22', 'resident#90', 'resident#14', 'rn#1']
# ['resident#22', 'nurse']
# ['staff#1', 'staff#2']
# ['dietary staff#2', 'staff#2']
# ['housekeeper#1', 'na#1', 'and#112', 'resident#112', 'lpn#1', 'rn#1', 'rooms#50']
# []
# ['resident#124', 'scheduler#1']
# []
# ['resident#1', 'lpn#1', 'rn#2']
# ['don']
# ['resident#1', 'lpn#1', 'rn#2', 'rn#1']
# ['don']
# ['resident#2', 'lpn#2', 'rn#1']
# ['lpn#2']
# ['resident#2', 'lpn#2', 'rn#1']
# ['lpn#2']
# ['resident#2', 'resident#1', 'na#1', 'and#2']
# ['don']
# ['resident#2', 'resident#1', 'na#1', 'and#2']
# ['don']
# ['staff#1', 'resident#597', 'na#3', 'resident#28']
# []
# ['resident#63', 'resident#34', 'rn#1']
# ['resident#63', 'resident#34']
# ['rn#5', 'resident#8', 'resident#93']
# ['resident#93']
# ['resident#299', 'pta#1']
# []
# ['resident#79', 'resident#299']
# ['loss)physician', 'resident#79', 'dietitian']
# ['lpn#2', 'lpn#1']
# ['lpn#2']
# ['contact#1', 'rn#3', 'person#2', 'contact#2', 'resident#40', 'person#1']
# []
# ['r#159', 'na#1', 'na#4', 'resident#33', 'and#159', 'na#3', 'na#2', 'resident#159']
# ['na#3']
# ['rn#15', 'includeresident#40', 'resident#40', 'md#1']
# ['resident#40']
# ['rn#4', 'resident#37', 'worker#1', 'rn#1']
# []
# ['resident#203']
# []
# []
# []
# []
# []
# ['rn#5', 'resident#176']
# []
# ['resident#69', 'na#8']

# %%
find_actors(txt_rep.loc[1,'inspection_text'])
# Out:
# ['person#4', 'na#7', 'r#227', 'sw#1', 'rn#1', 'lpn#3', 'na#6', 'resident#227']
# ['na#6', 'r#227']
# {'lpn#3', 'na#6', 'na#7', 'person#4', 'r#227', 'resident#227', 'rn#1', 'sw#1'}

# %%
# identify key actors in a given report -  OPTION 2 using spacy

# %%
def preprocess(sent):
    sent = nltk.word_tokenize(sent)
    sent = nltk.pos_tag(sent)
    return sent

# %%
for snt in nltk.sent_tokenize(txt_rep.loc[1,'inspection_text']):
    snt2=preprocess(snt)
    namedEnt = nltk.ne_chunk(snt2, binary=False)
    print(namedEnt.)
# Out:
# (S
#   */JJ
#   */NNP
#   note-/NN
#   terms/NNS
#   in/IN
#   brackets/NNS
#   have/VBP
#   been/VBN
#   edited/VBN
#   to/TO
#   protect/VB
#   confidentiality/NN
#   */NNP
#   */NNP
#   >/NNP
#   based/VBN
#   on/IN
#   clinical/JJ
#   record/NN
#   review/NN
#   ,/,
#   interviews/NNS
#   ,/,
#   review/NN
#   of/IN
#   facility/NN
#   documentation/NN
#   ,/,
#   and/CC
#   review/NN
#   of/IN
#   facility/NN
#   policy/NN
#   and/CC
#   procedure/NN
#   for/IN
#   one/CD
#   of/IN
#   three/CD
#   residents/NNS
#   reviewed/VBN
#   for/IN
#   dignity/NN
#   (/(
#   resident/JJ
#   #/#
#   227/CD
#   )/)
#   ,/,
#   the/DT
#   facility/NN
#   failed/VBD
#   to/TO
#   ensure/VB
#   a/DT
#   resident/NN
#   's/POS
#   grievance/concern/NN
#   was/VBD
#   acted/VBN
#   upon/IN
#   in/IN
#   accordance/NN
#   with/IN
#   facility/NN
#   policy/NN
#   and/CC
#   procedure/NN
#   ./.)
# (S
#   the/DT
#   findings/NNS
#   include/VBP
#   :/:
#   resident/JJ
#   #/#
#   227/CD
#   's/POS
#   [/JJ
#   diagnoses/NNS
#   redacted/VBD
#   ]/NN
#   ./.)
# (S
#   the/DT
#   quarterly/JJ
#   mds/NN
#   assessment/NN
#   dated/VBD
#   [/JJ
#   date/NN
#   ]/NNP
#   identified/VBD
#   the/DT
#   resident/NN
#   was/VBD
#   without/IN
#   cognitive/JJ
#   impairment/NN
#   ,/,
#   no/DT
#   behaviors/NNS
#   exhibited/VBD
#   ,/,
#   required/VBN
#   extensive/JJ
#   assistance/NN
#   with/IN
#   adl/NN
#   's/POS
#   ,/,
#   frequently/RB
#   incontinent/NN
#   of/IN
#   bladder/NN
#   and/CC
#   bowel/NN
#   ,/,
#   received/VBD
#   51/CD
#   %/NN
#   of/IN
#   total/JJ
#   calories/NNS
#   through/IN
#   tube/NN
#   feeding/NN
#   ,/,
#   received/VBD
#   an/DT
#   anti-anxiety/JJ
#   medication/NN
#   daily/RB
#   ./.)
# (S
#   the/DT
#   rcp/NN
#   dated/VBD
#   1/6/16/CD
#   identified/VBN
#   the/DT
#   need/NN
#   for/IN
#   assistance/NN
#   with/IN
#   adl/NNS
#   care/NN
#   related/VBN
#   to/TO
#   [/NNP
#   medical/JJ
#   condition/NN
#   ]/NN
#   ./.)
# (S
#   interventions/NNS
#   included/VBD
#   limited/JJ
#   assistance/NN
#   with/IN
#   ambulation/NN
#   ,/,
#   and/CC
#   transfers.review/NN
#   of/IN
#   facility/NN
#   grievance/concern/JJ
#   form/NN
#   dated/VBD
#   1/14/16/CD
#   identified/VBN
#   r/NN
#   #/#
#   227/CD
#   voiced/VBD
#   a/DT
#   concern/NN
#   to/TO
#   lpn/VB
#   #/#
#   3/CD
#   related/VBN
#   to/TO
#   na/RB
#   #/#
#   7/CD
#   's/POS
#   attitude/NN
#   when/WRB
#   providing/VBG
#   care/NN
#   ./.)
# (S
#   the/DT
#   documentation/NN
#   of/IN
#   the/DT
#   resolution/NN
#   of/IN
#   the/DT
#   grievance/concern/NN
#   noted/VBD
#   that/IN
#   lpn/JJ
#   #/#
#   3/CD
#   had/VBD
#   spoken/VBN
#   to/TO
#   na/VB
#   #/#
#   7/CD
#   regarding/VBG
#   his/her/JJR
#   tone/NN
#   while/IN
#   providing/VBG
#   care/NN
#   to/TO
#   r/VB
#   #/#
#   227/CD
#   ./.)
# (S
#   although/IN
#   the/DT
#   grievance/concern/JJ
#   form/NN
#   noted/VBD
#   that/IN
#   na/JJ
#   #/#
#   7/CD
#   was/VBD
#   spoken/VBN
#   to/TO
#   by/IN
#   lpn/JJ
#   #/#
#   3/CD
#   ,/,
#   the/DT
#   facility/NN
#   failed/VBD
#   to/TO
#   initiate/VB
#   an/DT
#   investigation/NN
#   and/or/NN
#   provide/VBP
#   documentation/NN
#   that/WDT
#   na/RB
#   #/#
#   7/CD
#   was/VBD
#   provided/VBN
#   with/IN
#   any/DT
#   education/counseling/NN
#   ./.)
# (S
#   review/NN
#   of/IN
#   facility/NN
#   grievance/NN
#   /concern/JJ
#   form/NN
#   dated/VBD
#   2/4/16/CD
#   noted/JJ
#   person/NN
#   #/#
#   4/CD
#   reported/VBD
#   to/TO
#   sw/VB
#   #/#
#   1/CD
#   a/DT
#   concern/NN
#   related/VBN
#   to/TO
#   na/RB
#   #/#
#   7/CD
#   's/POS
#   attitude/NN
#   with/IN
#   r/NN
#   #/#
#   227/CD
#   ./.)
# (S
#   the/DT
#   facility/NN
#   initiated/VBD
#   an/DT
#   investigation/NN
#   and/CC
#   identified/VBD
#   r/NN
#   #/#
#   227/CD
#   reported/VBD
#   na/JJ
#   #/#
#   7/CD
#   had/VBD
#   an/DT
#   attitude/NN
#   ,/,
#   is/VBZ
#   bossy/JJ
#   ,/,
#   as/RB
#   well/RB
#   as/IN
#   being/VBG
#   sarcastic/JJ
#   with/IN
#   him/her/NN
#   ./.)
# (S
#   r/NN
#   #/#
#   227/CD
#   reported/VBD
#   he/she/NN
#   feels/NNS
#   uncomfortable/JJ
#   when/WRB
#   na/RB
#   #/#
#   7/CD
#   comes/VBZ
#   into/IN
#   his/her/JJ
#   room/NN
#   ./.)
# (S
#   the/DT
#   facility/NN
#   's/POS
#   resolution/NN
#   was/VBD
#   to/TO
#   re-assign/JJ
#   na/JJ
#   #/#
#   7/CD
#   to/TO
#   another/DT
#   assignment.review/NN
#   of/IN
#   facility/NN
#   grievance/concern/JJ
#   form/NN
#   dated/VBD
#   2/12/16/CD
#   identified/VBN
#   r/NN
#   #/#
#   227/CD
#   reported/VBD
#   concerns/NNS
#   related/VBN
#   to/TO
#   the/DT
#   care/NN
#   provided/VBN
#   by/IN
#   na/JJ
#   #/#
#   6/CD
#   ./.)
# (S
#   the/DT
#   facility/NN
#   initiated/VBD
#   an/DT
#   investigation/NN
#   and/CC
#   r/NN
#   #/#
#   227/CD
#   's/POS
#   plan/NN
#   of/IN
#   care/NN
#   was/VBD
#   revised/VBN
#   to/TO
#   reflect/VB
#   two/CD
#   staff/NN
#   members/NNS
#   with/IN
#   care.review/NN
#   of/IN
#   facility/NN
#   grievance/NN
#   /concern/JJ
#   form/NN
#   dated/VBD
#   3/2/16/CD
#   identified/VBN
#   r/NN
#   #/#
#   227/CD
#   reported/VBD
#   na/JJ
#   #/#
#   6/CD
#   rushes/NNS
#   through/IN
#   care/NN
#   and/CC
#   na/RB
#   #/#
#   6/CD
#   verbalized/VBN
#   to/TO
#   r/VB
#   #/#
#   227/CD
#   he/she/NN
#   needed/VBD
#   to/TO
#   hurry/VB
#   so/RB
#   he/she/NN
#   could/MD
#   go/VB
#   to/TO
#   lunch/NN
#   ./.)
# (S
#   although/IN
#   the/DT
#   facility/NN
#   noted/VBD
#   na/RB
#   #/#
#   6/CD
#   would/MD
#   be/VB
#   removed/VBN
#   from/IN
#   providing/VBG
#   care/NN
#   to/TO
#   r/VB
#   #/#
#   227/CD
#   the/DT
#   facility/NN
#   failed/VBD
#   to/TO
#   initiate/VB
#   an/DT
#   investigation/NN
#   and/CC
#   failed/VBD
#   to/TO
#   follow/VB
#   the/DT
#   residents/NNS
#   plan/NN
#   of/IN
#   care/NN
#   to/TO
#   ensure/VB
#   two/CD
#   staff/NN
#   members/NNS
#   while/IN
#   providing/VBG
#   care.facility/NN
#   policy/NN
#   and/CC
#   procedure/NN
#   for/IN
#   completing/VBG
#   a/DT
#   grievance/concern/JJ
#   form/NN
#   identified/VBN
#   any/DT
#   resident/NN
#   or/CC
#   resident/NN
#   's/POS
#   representative/NN
#   has/VBZ
#   the/DT
#   right/NN
#   to/TO
#   express/VB
#   a/DT
#   grievance/NN
#   without/IN
#   fear/NN
#   of/IN
#   restraint/NN
#   ,/,
#   interference/NN
#   ,/,
#   coercion/NN
#   ,/,
#   discrimination/NN
#   ,/,
#   or/CC
#   reprisal/NN
#   in/IN
#   any/DT
#   form/NN
#   ./.)
# (S
#   upon/IN
#   receipt/NN
#   of/IN
#   the/DT
#   grievance/concern/NN
#   ,/,
#   the/DT
#   grievance/concern/JJ
#   form/NN
#   will/MD
#   be/VB
#   initiated/VBN
#   by/IN
#   the/DT
#   staff/NN
#   member/NN
#   receiving/VBG
#   the/DT
#   concern/NN
#   and/CC
#   documented/VBN
#   on/IN
#   the/DT
#   grievance/concern/JJ
#   log/NN
#   ./.)
# (S
#   the/DT
#   facility/NN
#   will/MD
#   contact/VB
#   the/DT
#   person/NN
#   filling/VBG
#   out/RP
#   the/DT
#   grievance/NN
#   to/TO
#   acknowledge/VB
#   receipt/NN
#   ,/,
#   investigate/VB
#   the/DT
#   grievance/NN
#   ,/,
#   and/CC
#   notify/VB
#   the/DT
#   person/NN
#   filing/VBG
#   the/DT
#   grievance/NN
#   of/IN
#   resolution/NN
#   within/IN
#   72/CD
#   hours/NNS
#   ./.)
# (S
#   completed/VBN
#   grievance/concern/JJ
#   forms/NNS
#   will/MD
#   be/VB
#   reviewed/VBN
#   and/CC
#   retained/VBN
#   by/IN
#   the/DT
#   center/NN
#   executive/NN
#   director/NN
#   to/TO
#   assure/VB
#   the/DT
#   resident/NN
#   's/POS
#   interests/NNS
#   have/VBP
#   been/VBN
#   addressed.interview/VBN
#   and/CC
#   review/NN
#   of/IN
#   the/DT
#   grievance/concern/JJ
#   form/NN
#   dated/VBD
#   1/14/16/CD
#   with/IN
#   lpn/JJ
#   #/#
#   3/CD
#   on/IN
#   11/17/16/CD
#   at/IN
#   1:45/CD
#   pm/NNS
#   indicated/VBD
#   when/WRB
#   a/DT
#   resident/family/JJ
#   member/NN
#   voices/NNS
#   a/DT
#   concern/complaint/NN
#   ,/,
#   a/DT
#   grievance/concern/JJ
#   form/NN
#   is/VBZ
#   completed/VBN
#   ,/,
#   an/DT
#   investigation/NN
#   is/VBZ
#   initiated/VBN
#   and/CC
#   depending/VBG
#   on/IN
#   the/DT
#   particular/JJ
#   concern/NN
#   ,/,
#   it/PRP
#   is/VBZ
#   forwarded/VBN
#   to/TO
#   appropriate/VB
#   departments/NNS
#   for/IN
#   follow/VBP
#   up/RP
#   ./.)
# (S
#   although/IN
#   lpn/JJ
#   #/#
#   3/CD
#   indicated/JJ
#   he/she/NN
#   had/VBD
#   spoken/VBN
#   to/TO
#   na/VB
#   #/#
#   7/CD
#   about/IN
#   r/NN
#   #/#
#   227/CD
#   's/POS
#   concerns/NNS
#   ,/,
#   the/DT
#   documentation/NN
#   failed/VBD
#   to/TO
#   reflect/VB
#   an/DT
#   investigation/NN
#   had/VBD
#   been/VBN
#   initiated/VBN
#   and/or/JJ
#   na/RB
#   #/#
#   7/CD
#   was/VBD
#   provided/VBN
#   with/IN
#   any/DT
#   education/counseling/VBG
#   related/VBN
#   to/TO
#   care/VB
#   and/CC
#   services.interview/VB
#   and/CC
#   review/VB
#   of/IN
#   grievance/concern/JJ
#   form/NN
#   dated/VBD
#   2/12/16/CD
#   ,/,
#   and/CC
#   3/2/16/CD
#   with/IN
#   rn/JJ
#   #/#
#   1/CD
#   on/IN
#   11/17/16/CD
#   at/IN
#   2:00/CD
#   pm/NNS
#   identified/VBN
#   he/she/RB
#   completed/VBD
#   a/DT
#   grievance/concern/JJ
#   form/NN
#   on/IN
#   2/12/16/CD
#   when/WRB
#   r/NN
#   #/#
#   227/CD
#   voiced/VBD
#   his/her/JJR
#   concerns/NNS
#   related/VBN
#   to/TO
#   the/DT
#   care/NN
#   provided/VBN
#   by/IN
#   na/JJ
#   #/#
#   6/CD
#   ./.)
# (S
#   an/DT
#   investigation/NN
#   was/VBD
#   initiated/VBN
#   and/CC
#   a/DT
#   revision/NN
#   to/TO
#   r/VB
#   #/#
#   227/CD
#   's/POS
#   plan/NN
#   of/IN
#   care/NN
#   was/VBD
#   done/VBN
#   to/TO
#   ensure/VB
#   two/CD
#   staff/NN
#   members/NNS
#   with/IN
#   care/NN
#   (/(
#   na/JJ
#   #/#
#   6/CD
#   was/VBD
#   not/RB
#   removed/VBN
#   from/IN
#   caring/VBG
#   for/IN
#   the/DT
#   resident/NN
#   )/)
#   ./.)
# (S
#   the/DT
#   grievance/concern/JJ
#   form/NN
#   dated/VBD
#   3/2/16/CD
#   noted/JJ
#   r/NN
#   #/#
#   227/CD
#   voiced/VBD
#   a/DT
#   concern/NN
#   that/WDT
#   na/RB
#   #/#
#   6/CD
#   rushes/NNS
#   through/IN
#   care/NN
#   and/CC
#   na/RB
#   #/#
#   6/CD
#   verbalized/VBD
#   his/her/RB
#   need/NN
#   to/TO
#   hurry/VB
#   so/RB
#   he/she/JJ
#   can/MD
#   go/VB
#   to/TO
#   lunch/NN
#   ./.)
# (S
#   rn/NN
#   #/#
#   1/CD
#   indicated/VBD
#   an/DT
#   investigation/NN
#   was/VBD
#   completed/VBN
#   and/CC
#   na/JJ
#   #/#
#   6/CD
#   was/VBD
#   removed/VBN
#   from/IN
#   r/NN
#   #/#
#   227/CD
#   's/POS
#   assignment/NN
#   at/IN
#   that/DT
#   time/NN
#   ./.)
# (S
#   although/IN
#   rn/JJ
#   #/#
#   1/CD
#   indicated/VBD
#   the/DT
#   facility/NN
#   initiated/VBD
#   an/DT
#   investigation/NN
#   and/CC
#   removed/VBD
#   na/RB
#   #/#
#   6/CD
#   from/IN
#   r/NN
#   #/#
#   227/CD
#   's/POS
#   assignment/NN
#   ,/,
#   the/DT
#   facility/NN
#   documentation/NN
#   failed/VBD
#   to/TO
#   reflect/VB
#   an/DT
#   investigation/NN
#   was/VBD
#   completed/VBN
#   ./.)

# %%
doc_sent1=nltk.sent_tokenize(dat.loc[1,'inspection_text'])

# %%
sent5=doc_sent1[5]

# %%
tokenizer = nltk.tokenize.RegexpTokenizer(r'\w+\s?\#\d+')

# %%
sent = tokenizer.tokenize(sent5)
sent2 = nltk.pos_tag(sent)

# %%
sent
# Out:
# ['LPN #3', 'NA #7', 'R #227']

# %%
nltk.ne_chunk(sent, binary=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/opt/miniconda3/envs/nh_2567/lib/python3.10/site-packages/IPython/core/formatters.py:344, in BaseFormatter.__call__(self, obj)
#     342     method = get_real_method(obj, self.print_method)
#     343     if method is not None:
# --> 344         return method()
#     345     return None
#     346 else:
#
# File ~/opt/miniconda3/envs/nh_2567/lib/python3.10/site-packages/nltk/tree/tree.py:782, in Tree._repr_svg_(self)
#     781 def _repr_svg_(self):
# --> 782     from svgling import draw_tree
#     784     return draw_tree(self)._repr_svg_()
#
# ModuleNotFoundError: No module named 'svgling'
# Tree('S', [('The', 'DT'), ('documentation', 'NN'), ('of', 'IN'), ('the', 'DT'), ('resolution', 'NN'), ('of', 'IN'), ('the', 'DT'), ('grievance/concern', 'NN'), ('noted', 'VBD'), ('that', 'IN'), Tree('NE', [('LPN', 'NNP')]), ('#', '#'), ('3', 'CD'), ('had', 'VBD'), ('spoken', 'VBN'), ('to', 'TO'), ('NA', 'NNP'), ('#', '#'), ('7', 'CD'), ('regarding', 'VBG'), ('his/her', 'JJR'), ('tone', 'NN'), ('while', 'IN'), ('providing', 'VBG'), ('care', 'NN'), ('to', 'TO'), ('R', 'NNP'), ('#', '#'), ('227', 'CD'), ('.', '.')])

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/opt/miniconda3/envs/nh_2567/lib/python3.10/site-packages/IPython/core/formatters.py:344, in BaseFormatter.__call__(self, obj)
#     342     method = get_real_method(obj, self.print_method)
#     343     if method is not None:
# --> 344         return method()
#     345     return None
#     346 else:
#
# File ~/opt/miniconda3/envs/nh_2567/lib/python3.10/site-packages/nltk/tree/tree.py:782, in Tree._repr_svg_(self)
#     781 def _repr_svg_(self):
# --> 782     from svgling import draw_tree
#     784     return draw_tree(self)._repr_svg_()
#
# ModuleNotFoundError: No module named 'svgling'
# Tree('S', [('The', 'DT'), ('documentation', 'NN'), ('of', 'IN'), ('the', 'DT'), ('resolution', 'NN'), ('of', 'IN'), ('the', 'DT'), ('grievance/concern', 'NN'), ('noted', 'VBD'), ('that', 'IN'), Tree('NE', [('LPN', 'NNP')]), ('#', '#'), ('3', 'CD'), ('had', 'VBD'), ('spoken', 'VBN'), ('to', 'TO'), ('NA', 'NNP'), ('#', '#'), ('7', 'CD'), ('regarding', 'VBG'), ('his/her', 'JJR'), ('tone', 'NN'), ('while', 'IN'), ('providing', 'VBG'), ('care', 'NN'), ('to', 'TO'), ('R', 'NNP'), ('#', '#'), ('227', 'CD'), ('.', '.')])

# %% [markdown]
# **building a network of actors for each complaint**
# approach is to look for the actors listed in actors columns
# 1. find if they are in a sentence together
# 2. if they are then make a direct link,
# 3. moreover if the sentence is active voice -- make a directed edge!

# %%
sent_tokenize(txt_rep.inspection_text[0])
# Out:
# ["**note- terms in brackets have been edited to protect confidentiality** based on review of the clinical record and interview for one of three sampled residents with a change in condition (r#312), the facility failed to report to the physician when the resident had a change in condition and the resident's insulin was held in violation of the physician's orders [redacted].",
#  "resident#312's [diagnoses redacted].",
#  'the resident care plan dated 5/20/16 identified the resident had insulin dependent diabetes.',
#  'interventions directed the staff to administer medications as ordered, monitor for signs and symptoms of hypo/[medical condition], and report abnormal findings to the physician.',
#  "physician's orders [redacted].the admission mds dated [date] identified the resident was without cognitive impairment, was independent with bed mobility and transfers and eating, required supervision for dressing and personal hygiene and physical help in part of the bathing activity.physician orders [redacted].",
#  "if blood sugar is between 350-400, give an extra 2 units and if between 401-450, give extra 4 units.nurse's notes dated 6/11/16 at 11:30 pm identified that the resident was very sleepy all shift (3:00 pm to 11:00 pm).",
#  'blood sugars were checked and were within normal range.',
#  'the resident ate 50% of supper.',
#  "the mar for 6/11/16 identified the resident's blood sugar was 157 at 4:30 pm.",
#  "the nurse's notes lacked documentation of a complete assessment when the resident presented with a change in mental status and/or that the physician had been notified of a change.",
#  "additionally, the subsequent shift, 6/12/16 on 11:00 pm to 7:00 am, failed to follow up and/or conduct an assessment of the resident's condition.nurse's notes and the mar indicated [redacted].",
#  "the nurse's notes indicated that the resident was verbally responsive, food and fluids were given and the blood sugar was rechecked and was 130. although the shift supervisor was notified that the resident's insulin was held on 2 occasions, there was no documentation of a complete assessment of the resident's condition and/or physician notification that the insulin was being held for blood sugars that were not less than 70 as directed by physician orders.nurse's notes dated 6/12/16 identified that at 3:45 pm the resident was found unresponsive, without a pulse or respirations.",
#  '911 was activated, compressions and ventilation were initiated and a blood sugar of 213 was noted.',
#  'ems arrived at 3:55 and the resident was transferred to the ed.interview on 11/16/16 at 2:00 pm with person#1 identified that on 6/11/16 the resident was so unresponsive that lpn#1 had a difficult time arousing her/him.',
#  'interview and review of the clinical record on 11/17/16 at 1:30 pm with lpn#1 identified it was communicated during the shift report (on 6/11/16) that the resident was sleepy all day.',
#  'lpn#1 indicated that the resident was usually totally alert, but was very lethargic all evening.',
#  "additionally, lpn#1 stated she/he did not notify the physician of the resident's change in condition.interview and review of the clinical record on 11/17/16 at 12:30 pm with lpn#2 identified although the physician's orders [redacted].",
#  'sugars were usually higher and the resident was not eating.',
#  'lpn#2 notified the supervisor but did not notify the physician.',
#  'the supervisor on duty on 6/12/16 was not available for interview.interview and review of the clinical record on 11/17/16 at 12:30 pm with the dns and adns identified a full assessment should be conducted when the resident had a change in condition and the physician should be notified.',
#  "it was a nursing judgement to hold the resident's insulin and lpn#2 should have assured that the physician was notified."]

# %%
from transformers import AutoModel, AutoTokenizer, AutoModelForTokenClassification
model_blue = "distilbert-base-uncased"
tokenize = AutoTokenizer.from_pretrained(
    model_blue, use_fast=True, add_prefix_space=True
)

# %%
import nltk
from nltk.tokenize import wordpunct_tokenize, word_tokenize, RegexpTokenizer, MWETokenizer, sent_tokenize
from nltk.tag import pos_tag, pos_tag_sents

# %%
te = """R#227 voiced a concern to LPN#3 related to NA#7's attitude when providing care. Hello there!"""
wordpunct_tokenize(te)
pos_tag(sent_tokenize(te))
# Out:
# [("R#227 voiced a concern to LPN#3 related to NA#7's attitude when providing care.",
#   'NNP'),
#  ('Hello there!', 'NNP')]

# %%
grammar = r"""chunk1: {<NN><WRB><VBG><NN>}"""

# %%
dat['inspection_date']=pd.to_datetime(dat.inspection_date)

# %%
dat['inspection_year']=dat.inspection_date.dt.year

# %%
dat.inspection_year.value_counts()
# Out:
# 2018    5599
# 2017    4521
# 2016    3684
# 2019     968
# 2015     651
# Name: inspection_year, dtype: int64
